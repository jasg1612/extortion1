# %%
def identificar_oracion(oracion):
  verbos_pasivos = ["es", "fue", "seria", "son", "serian", "ha sido", "habia sido", "se","sera","fueron","seran"]
  verbos_pasivos_demanda=["hace","pagada"] ##la plata es pagada por
  verbos_pasivos_amenaza=["golpeado","una","golpeados","raptado"]
  ###imperativo pasivo
  verbos_pasivos_imperativos_demanda=["des","pagame","depositame","llamame","manda","negociamos"]
  ###tacito
  verbos_activos_demanda=["trae","consigue","vale","yapea","plinea","pagar","pedimos","tienes","rompe","pagarme","pagaron","quedar","has","suelta","colaboras","colabora","colaborar",
                          "pagas","paga","pagues","esperes","juega","afloja","caera","deposite","depositas","llegamos","contestas","deposita"]
  ##el verbo daré es amenaza por ser en primera persona lo que es imposble tener al forma a la persona extorsionada
  verbos_activos_amenaza=["demando","sufriras","sufriras","secuestrar","secuestraria","hare","tragar","fuiste","volamos","matarlos","reventamos","reviento","desaparecio","desaparecerte","cae",
                          "desaparezco","cumple","fallaremos","revienta","metemos","dare","quemamos","puede","quieres","denuncias","jodes","atente","juegues","valoras","volará",
                          "mueres","regala","morir","mato","mate","llego","matare","matando","enfriamos","volar","ire","verte","exigo","ordena",
                          "demandare","requiero","mando","mande","ofrece","matamos","sabemos","estamos","comprendemos","venimos","conocemos","llamo","recoger","tengo","tenemos",
                          "enfriar","meterte","cortaremos"]

  ##sujeto amenaza
  sujeto_amenaza=["cupo","consecuencias","calavera","frios","frio","cabeza","duele","muerte","bomba"]##estos sujetos estan acompañados del verbo mixto dejo, entrego, tiene
  verbo_sujeto_amenaza=["sufriran","dejo","entrego","encargo","tiene","veran","vera","recibir","sera","dimos","paga","dejare","explotar"]

  ##sujeto demanda
  sujeto_demanda=["colaboracion","cupo","dinero"]##estos sujetos estan acompañados del verbo mixto dejo, entrego, tiene
  verbo_sujeto_demanda=["indicarle","paga","pagar","es importante","entrega","deposita"]

###afectado-familiar,negocio o propiedad de la persona extorsionada
  sujeto_afectado=["negocio","propiedad","esposa","chibolos","familia","familias","hijo","hija","hijos","sobrino","sobrinos","sobrinas","sobrina","hijas","suegra","mama","papa",
                   "nieto","nieta","casa","carro"]
  verbos_afectados=["explotar","quemar","explosionar","despidete","salen","pudran","caera","matare","matamos","matar","pagar","matarte","matando","atente","depende","secuestrar",
                    "secuestraria","muere","volare","secuestrare","pagan","atentado","esta","desaparecio","cortaremos"]###pagar es sinonimo de matar te haremos pagar todo
###demas
  preposiciones = ["a", "ante", "bajo", "cabe", "con", "contra", "de", "desde", "durante", "en", "entre", "hacia", "hasta", "mediante", "para", "por", "segun", "sin", "so",
                   "sobre", "tras"]  # Puedes ampliar esta lista según necesites
  adverbios = ["rapidamente", "lentamente", "mañana", "tarde", "nunca", "siempre","si no","si","no"]  # Puedes ampliar esta lista según necesites
  determinantes=["el", "la", "los", "las","un", "una", "unos", "unas","este", "ese", "aquel" ,"mi", "tu", "su", "nuestro", "uno", "dos", "tres"]
  verbo_infinito=["voy","vas","va","vamos","vais","van"]
  conjunciones=["y", "porque"]
  verbos_no_extorsivos=["vivirás"]
  pronombres_personales=["te"]
  palabras = oracion.lower().split()
  index=0
  val=0
  for palabra in palabras:
    try:
      index=index+1
      ###regla01: verbos "ser" o "estar" + participio pasado del verbo principal, tu hijo será golpeado (amenaza)
      if palabra in verbos_pasivos:
        siguiente = palabras[index]
        ##amenaza
        if siguiente.lower() in verbos_pasivos_amenaza: #esta ultima parte es para el <<por>>
           ###obtencion de las partes de la oracion
           verbo = siguiente
           sujeto = "extorsionador"
           val=1
           i=0
           sujeto_pasivo=" "###es el sujeto del activo
           while i<=len(palabras[:index]):
             if palabras[index - i] not in verbos_activos_demanda and palabras[index - i] not in verbos_activos_amenaza\
             and palabras[index - i] not in verbos_pasivos_imperativos_demanda and\
             palabras[index - i] not in preposiciones and palabras[index - i] not in adverbios and palabras[index - i] not in determinantes and palabras[index - i] not in verbo_infinito\
             and palabras[index - i] not in verbos_no_extorsivos and palabras[index - i] not in conjunciones:
               sujeto_pasivo = sujeto_pasivo+" "+palabras[index - i]
             i=i+1
           print("sujeto"," ",sujeto," ","verbo",verbo," ","sujeto_pasivo"," ",sujeto_pasivo," ","amenaza pasivo")



      #demanda
        if siguiente.lower() in verbos_pasivos_demanda: #esta ultima parte es para el <<por>>
           verbo = siguiente
           #####obtener sujeto###
           sujeto = "persona extorsionada"
           val=1
           i=0
           sujeto_pasivo=" "###es el sujeto del activo
           while i<=len(palabras[:index]):
             if palabras[index - i] not in verbos_activos_demanda and palabras[index - i] not in verbos_activos_amenaza\
             and palabras[index - i] not in verbos_pasivos_imperativos_demanda and\
             palabras[index - i] not in preposiciones and palabras[index - i] not in adverbios and palabras[index - i] not in determinantes and palabras[index - i] not in verbo_infinito\
             and palabras[index - i] not in verbos_no_extorsivos and palabras[index - i] not in conjunciones:
               sujeto_pasivo = sujeto_pasivo+" "+palabras[index - i]
             i=i+1
           print("sujeto"," ",sujeto," ","verbo",verbo," ","sujeto_pasivo"," ",sujeto_pasivo," ","amenaza pasivo")


      ###regla02:cuando los verbos son imperativos.. demanda.
      if palabra.lower() in verbos_pasivos_imperativos_demanda :
        verbo = palabra
        sujeto = "extorsionador"
        val=1
        i=0
        sustantivo=" "
        while i<len(palabras[index:]):
          if palabras[index + i] not in verbos_activos_demanda and palabras[index + i] not in verbos_activos_amenaza\
          and palabras[index + i] not in verbos_pasivos_imperativos_demanda and\
          palabras[index + i] not in preposiciones and palabras[index + i] not in adverbios and palabras[index + i] not in determinantes and palabras[index + i] not in verbo_infinito\
          and palabras[index + i] not in verbos_no_extorsivos and palabras[index + i] not in conjunciones:
            sustantivo = sustantivo+" "+palabras[index + i]

          i=i+1
        print("sujeto"," ",sujeto," ","verbo",verbo," ","sustantivo"," ",sustantivo," ","demanda pasivo imperativo")


      ###regla 3 verbo activo con sujeto tacito/no tacito si se requiere saber del sujeto demanda/amenaza
      ###demanda
      if palabra.lower() in verbos_activos_demanda:
        #####obtener verbo###
        verbo = palabra
        print(verbo)
        ###obtener sujeto, si fuera el caso de una oracion no tacita
        sujeto=" "###es el sujeto del activo
        indice = index
        longitud = len(palabras)
        direccion = "adelante"
        # Bucle while
        for indice in range(0, longitud):
            # Controlar la dirección

            if direccion == "adelante":
                indice += 1
                # Imprimir el elemento actual
                if indice == longitud:
                    # Cambiar la dirección al final de la lista
                    direccion = "atras"
                    indice -= 1  # Ajustar el índice para el recorrido hacia atrás
                    continue
                if  palabras[indice] in verbos_activos_demanda:###este sujeto lo convierte en amenaza
                  #####obtener sujeto###
                  sujeto = "persona extorsionada"
                  val=1
                  #####obtener sustantivo###
                  i=0
                  sustantivo=" "
                  while i<len(palabras[indice:]):
                    if palabras[indice + i] not in verbos_activos_demanda and palabras[indice + i] not in verbos_activos_amenaza \
                    and  palabras[indice + i] not in verbos_pasivos_imperativos_demanda:
                      sustantivo = sustantivo+" "+palabras[indice + i]
                    i=i+1
                  # Inserting the new row
                  print("sujeto"," ",sujeto," ","verbo",verbo," ","sustantivo"," ",sustantivo," ","demanda")


                  continue
            elif direccion == "atras":
                indice -= 1
                if  palabras[indice] in verbos_activos_demanda:###este sujeto lo convierte en amenaza
                  #####obtener sujeto###
                  sujeto = "persona extorsionada"
                  val=1
                  #####obtener sustantivo###
                  i=0
                  sustantivo=" "
                  while i<len(palabras[indice:]):
                    if palabras[indice + i] not in verbos_activos_demanda and palabras[indice + i] not in verbos_activos_amenaza \
                    and  palabras[indice + i] not in verbos_pasivos_imperativos_demanda:
                      sustantivo = sustantivo+" "+palabras[indice + i]
                    i=i+1
                  print("sujeto"," ",sujeto," ","verbo",verbo," ","sustantivo"," ",sustantivo," ","sujeto amenaza")


     ###REGLA 03 verbo activo con sujeto tacito/no tacito si se requiere saber del sujeto demanda/amenaza
     #amenaza
      if palabra.lower() in verbos_activos_amenaza:
        #####obtener verbo###
        verbo = palabra
        ###obtener sujeto, si fuera el caso de una oracion no tacita
        sujeto=" "###es el sujeto del activo
        indice = index
        longitud = len(palabras)
        direccion = "adelante"
        # Bucle while
        for indice in range(0, longitud):
            # Controlar la dirección
            if direccion == "adelante":
                indice += 1
                # Imprimir el elemento actual
                if indice == longitud:
                    # Cambiar la dirección al final de la lista
                    direccion = "atras"
                    indice -= 1  # Ajustar el índice para el recorrido hacia atrás
                    continue
                if  palabras[indice] in verbos_activos_amenaza:###este sujeto lo convierte en amenaza
                  #####obtener sujeto###
                  sujeto = "extorsionador"
                  val=1
                  #####obtener sustantivo###
                  i=0
                  sustantivo=" "
                  while i<len(palabras[indice:]):
                    if palabras[indice + i] not in verbos_activos_demanda and palabras[indice + i] not in verbos_activos_amenaza \
                    and  palabras[indice + i] not in verbos_pasivos_imperativos_demanda:
                      sustantivo = sustantivo+" "+palabras[indice + i]
                    i=i+1
                  print("sujeto"," ",sujeto," ","verbo",verbo," ","sustantivo"," ",sustantivo," ","amenaza")


                  continue
            elif direccion == "atras":
                indice -= 1
                if  palabras[indice] in verbos_activos_amenaza:###este sujeto lo convierte en amenaza
                  #####obtener sujeto###
                  sujeto = "extorsionador"
                  val=1
                  #####obtener sustantivo###
                  i=0
                  sustantivo=" "
                  while i<len(palabras[indice:]):
                    if palabras[indice + i] not in verbos_activos_demanda and palabras[indice + i] not in verbos_activos_amenaza \
                    and  palabras[indice + i] not in verbos_pasivos_imperativos_demanda:
                      sustantivo = sustantivo+" "+palabras[indice + i]
                    i=i+1
                  print("sujeto"," ",sujeto," ","verbo",verbo," ","sustantivo"," ",sustantivo," ","sujeto amenaza")



      ###regla 4 sujeto amenaza y verbo mixto (demanda/amenaza)
      elif palabra.lower() in verbo_sujeto_amenaza :###el verbo mixto que no necesariamente es de extorsion
        #####obtener verbo###
        verbo = palabra
        # Inicialización del índice
        indice = index
        longitud = len(palabras)
        direccion = "adelante"
        # Bucle while
        while indice >= 0 and indice < longitud:
            # Controlar la dirección
            if direccion == "adelante":
                indice += 1
                # Imprimir el elemento actual
                if indice == longitud:
                    # Cambiar la dirección al final de la lista
                    direccion = "atras"
                    indice -= 1  # Ajustar el índice para el recorrido hacia atrás
                    continue
                if  palabras[indice] in sujeto_amenaza:###este sujeto lo convierte en amenaza
                  #####obtener sujeto###
                  sujeto = "extorsionador"
                  val=1
                  #####obtener sustantivo###
                  i=0
                  sustantivo=" "
                  while i<len(palabras[indice:]):
                    if palabras[indice + i] not in verbos_activos_demanda and palabras[indice + i] not in verbos_activos_amenaza \
                    and  palabras[indice + i] not in verbos_pasivos_imperativos_demanda:
                      sustantivo = sustantivo+" "+palabras[indice + i]
                    i=i+1
                  print("sujeto"," ",sujeto," ","verbo",verbo," ","sustantivo"," ",sustantivo," ","sujeto amenaza")


            elif direccion == "atras":
                indice -= 1
                if  palabras[indice] in sujeto_amenaza:###este sujeto lo convierte en amenaza
                  #####obtener sujeto###
                  sujeto = "extorsionador"
                  val=1
                  #####obtener sustantivo###
                  i=0
                  sustantivo=" "
                  while i<len(palabras[indice:]):
                    if palabras[indice + i] not in verbos_activos_demanda and palabras[indice + i] not in verbos_activos_amenaza \
                    and  palabras[indice + i] not in verbos_pasivos_imperativos_demanda:
                      sustantivo = sustantivo+" "+palabras[indice + i]
                    i=i+1
                  print("sujeto"," ",sujeto," ","verbo",verbo," ","sustantivo"," ",sustantivo," ","sujeto amenaza")


                if indice < 0:
                    break

###regla 5 sujeto demanda y verbo mixto (demanda/amenaza)
      elif palabra.lower() in verbo_sujeto_demanda:###el verbo mixto que no necesariamente es de extorsion
        #####obtener verbo###
        verbo = palabra
        # Inicialización del índice
        indice = index
        longitud = len(palabras)
        direccion = "adelante"
        # Bucle while
        while indice >= 0 and indice < longitud:
            # Controlar la dirección
            if direccion == "adelante":
                indice += 1
                # Imprimir el elemento actual
                if indice == longitud:
                    # Cambiar la dirección al final de la lista
                    direccion = "atras"
                    indice -= 1  # Ajustar el índice para el recorrido hacia atrás
                    continue
                if  palabras[indice] in sujeto_demanda:###este sujeto lo convierte en amenaza
                  #####obtener sujeto###
                  sujeto = "persona extorsionada"
                  val=1
                  #####obtener sustantivo###
                  i=0
                  sustantivo=" "
                  while i<len(palabras[indice:]):
                    if palabras[indice + i] not in verbos_activos_demanda and palabras[indice + i] not in verbos_activos_amenaza \
                    and  palabras[indice + i] not in verbos_pasivos_imperativos_demanda:
                      sustantivo = sustantivo+" "+palabras[indice + i]
                    i=i+1
                  print("sujeto"," ",sujeto," ","verbo",verbo," ","sustantivo"," ",sustantivo," ","sujeto amenaza")


                  continue
            elif direccion == "atras":
                indice -= 1
                if  palabras[indice] in sujeto_demanda:###este sujeto lo convierte en amenaza
                  #####obtener sujeto###
                  sujeto = "persona extorsionada"
                  val=1
                  #####obtener sustantivo###
                  i=0
                  sustantivo=" "
                  while i<len(palabras[indice:]):
                    if palabras[indice + i] not in verbos_activos_demanda and palabras[indice + i] not in verbos_activos_amenaza \
                    and  palabras[indice + i] not in verbos_pasivos_imperativos_demanda:
                      sustantivo = sustantivo+" "+palabras[indice + i]
                    i=i+1
                  print("sujeto"," ",sujeto," ","verbo",verbo," ","sustantivo"," ",sustantivo," ","sujeto amenaza")

                if indice < 0:
                    break

      #regla 6:afectado
      elif palabra.lower() in sujeto_afectado:
          sujeto2=palabras[index-1].lower()
          i=0
          while i<len(palabras[index:]):
            if palabras[index + i] in verbos_afectados:
              accion=palabras[index + i]
              val=1
              print("familia")

              break
            i=i+1

          ####
          i=0

          while i<=len(palabras[:index]):
            if palabras[index - i] in verbos_afectados:
              accion=palabras[index - i]
              val=1
              print("familia")

              break
            i=i+1

      #regla 7:condicional compuesta:preposicion principal y secundaria
      elif palabra.lower() == "si":
          tipo="X"
          siguiente = palabras[index]
          ##preposicion secundaria
          if siguiente=="no":
            val=1
            preposicion_secundaria = "si no"+" "+palabras[index+1]
            ###determinar la naturaleza de la oracion
            if palabras[index+1].lower() in verbos_activos_demanda:
              #print("demanda")
              tipo="D"
            if palabras[index+1].lower() in verbos_activos_amenaza :
              #print("amenaza")
              tipo="A"

            ###preposicion principal
            index2=index+2
            preposicion_principal=" "
            while index2<len(palabras):
              preposicion_principal = preposicion_principal+" "+palabras[index2]
              ###determinar la naturaleza de la oracion
              if palabras[index2].lower() in verbos_activos_demanda:
                #print("demanda")
                tipo="D"
              if palabras[index2].lower() in verbos_activos_amenaza :
                #print("amenaza")
                tipo="A"
              index2=index2+1
            print("preposicion_principal"," ",preposicion_principal," ","preposicion_secundaria:"," ", preposicion_secundaria)
    except IndexError:
      pass
    continue

  if val==0:
     print("NE")

# %%
identificar_oracion("a tu hija le cortaremos los dedos paga o yapea ahora reconchatumare")
# Out:
# familia
# sujeto   extorsionador   verbo cortaremos   sustantivo     los dedos o ahora reconchatumare   amenaza
# paga
# sujeto   persona extorsionada   verbo paga   sustantivo     o ahora reconchatumare   demanda
# sujeto   persona extorsionada   verbo paga   sustantivo     ahora reconchatumare   demanda
# yapea
# sujeto   persona extorsionada   verbo yapea   sustantivo     o ahora reconchatumare   demanda
# sujeto   persona extorsionada   verbo yapea   sustantivo     ahora reconchatumare   demanda
